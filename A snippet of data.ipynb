# %%
import pandas as pd

# %%
df = pd.read_csv('yammer_events.csv')

# %%
print(df)
# Out:
#     user_id      occurred_at  event_type           event_name       location  \
# 0     10522   2/5/2014 11:02  engagement                login          Japan
# 1     10522   2/5/2014 11:02  engagement            home_page          Japan
# 2     10522   2/5/2014 11:03  engagement         like_message          Japan
# 3     10522   2/5/2014 11:04  engagement           view_inbox          Japan
# 4     10522   2/5/2014 11:03  engagement           search_run          Japan
# 5     10522   2/5/2014 11:03  engagement           search_run          Japan
# 6     10612    1/5/2014 9:59  engagement                login    Netherlands
# 7     10612   1/5/2014 10:00  engagement         like_message    Netherlands
# 8     10612   1/5/2014 10:00  engagement         send_message    Netherlands
# 9     10612   1/5/2014 10:01  engagement            home_page    Netherlands
# 10    10612   1/5/2014 10:01  engagement         like_message    Netherlands
# ...
